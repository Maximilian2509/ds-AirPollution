# %% [markdown]
# # Model 1
#
# XGB Boost Model

# %%
! pip install -r requirements.txt
# Out:
# Requirement already satisfied: altair==5.0.1 in ./.venv/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (5.0.1)
# Requirement already satisfied: jupyterlab==3.6.3 in ./.venv/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (3.6.3)
# Requirement already satisfied: ipywidgets==8.0.6 in ./.venv/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (8.0.6)
# Requirement already satisfied: matplotlib==3.7.1 in ./.venv/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (3.7.1)
# Requirement already satisfied: seaborn==0.12.2 in ./.venv/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (0.12.2)
# Requirement already satisfied: numpy==1.24.3 in ./.venv/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (1.24.3)
# Requirement already satisfied: pandas==2.0.1 in ./.venv/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (2.0.1)
# Requirement already satisfied: jupyterlab-dash==0.1.0a3 in ./.venv/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (0.1.0a3)
# Requirement already satisfied: scikit-learn==1.2.2 in ./.venv/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (1.2.2)
# Requirement already satisfied: statsmodels==0.13.5 in ./.venv/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (0.13.5)
# Requirement already satisfied: pytest==7.3.1 in ./.venv/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (7.3.1)
# Requirement already satisfied: missingno==0.5.2 in ./.venv/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (0.5.2)
# Requirement already satisfied: XGBoost==1.7.5 in ./.venv/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (1.7.5)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.11/site-packages (from altair==5.0.1->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in ./.venv/lib/python3.11/site-packages (from altair==5.0.1->-r requirements.txt (line 1)) (4.23.0)
# Requirement already satisfied: toolz in ./.venv/lib/python3.11/site-packages (from altair==5.0.1->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: ipython in ./.venv/lib/python3.11/site-packages (from jupyterlab==3.6.3->-r requirements.txt (line 2)) (9.0.2)
# Requirement already satisfied: packaging in ./.venv/lib/python3.11/site-packages (from jupyterlab==3.6.3->-r requirements.txt (line 2)) (24.2)
# Requirement already satisfied: tornado>=6.1.0 in ./.venv/lib/python3.11/site-packages (from jupyterlab==3.6.3->-r requirements.txt (line 2)) (6.4.2)
# Requirement already satisfied: jupyter-core in ./.venv/lib/python3.11/site-packages (from jupyterlab==3.6.3->-r requirements.txt (line 2)) (5.7.2)
# Requirement already satisfied: jupyterlab-server~=2.19 in ./.venv/lib/python3.11/site-packages (from jupyterlab==3.6.3->-r requirements.txt (line 2)) (2.27.3)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in ./.venv/lib/python3.11/site-packages (from jupyterlab==3.6.3->-r requirements.txt (line 2)) (2.15.0)
# Requirement already satisfied: jupyter-ydoc~=0.2.3 in ./.venv/lib/python3.11/site-packages (from jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.2.5)
# Requirement already satisfied: jupyter-server-ydoc~=0.8.0 in ./.venv/lib/python3.11/site-packages (from jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.8.0)
# Requirement already satisfied: nbclassic in ./.venv/lib/python3.11/site-packages (from jupyterlab==3.6.3->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: notebook<7 in ./.venv/lib/python3.11/site-packages (from jupyterlab==3.6.3->-r requirements.txt (line 2)) (6.5.7)
# Requirement already satisfied: ipykernel>=4.5.1 in ./.venv/lib/python3.11/site-packages (from ipywidgets==8.0.6->-r requirements.txt (line 3)) (6.29.5)
# Requirement already satisfied: traitlets>=4.3.1 in ./.venv/lib/python3.11/site-packages (from ipywidgets==8.0.6->-r requirements.txt (line 3)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in ./.venv/lib/python3.11/site-packages (from ipywidgets==8.0.6->-r requirements.txt (line 3)) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in ./.venv/lib/python3.11/site-packages (from ipywidgets==8.0.6->-r requirements.txt (line 3)) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib==3.7.1->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.11/site-packages (from matplotlib==3.7.1->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.11/site-packages (from matplotlib==3.7.1->-r requirements.txt (line 4)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib==3.7.1->-r requirements.txt (line 4)) (1.4.8)
# Requirement already satisfied: pillow>=6.2.0 in ./.venv/lib/python3.11/site-packages (from matplotlib==3.7.1->-r requirements.txt (line 4)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib==3.7.1->-r requirements.txt (line 4)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.11/site-packages (from matplotlib==3.7.1->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.11/site-packages (from pandas==2.0.1->-r requirements.txt (line 7)) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.11/site-packages (from pandas==2.0.1->-r requirements.txt (line 7)) (2025.2)
# Requirement already satisfied: dash in ./.venv/lib/python3.11/site-packages (from jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (3.0.2)
# Requirement already satisfied: jupyter-server-proxy in ./.venv/lib/python3.11/site-packages (from jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (4.4.0)
# Requirement already satisfied: scipy>=1.3.2 in ./.venv/lib/python3.11/site-packages (from scikit-learn==1.2.2->-r requirements.txt (line 9)) (1.15.2)
# Requirement already satisfied: joblib>=1.1.1 in ./.venv/lib/python3.11/site-packages (from scikit-learn==1.2.2->-r requirements.txt (line 9)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn==1.2.2->-r requirements.txt (line 9)) (3.6.0)
# Requirement already satisfied: patsy>=0.5.2 in ./.venv/lib/python3.11/site-packages (from statsmodels==0.13.5->-r requirements.txt (line 10)) (1.0.1)
# Requirement already satisfied: iniconfig in ./.venv/lib/python3.11/site-packages (from pytest==7.3.1->-r requirements.txt (line 11)) (2.1.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in ./.venv/lib/python3.11/site-packages (from pytest==7.3.1->-r requirements.txt (line 11)) (1.5.0)
# Requirement already satisfied: appnope in ./.venv/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6->-r requirements.txt (line 3)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6->-r requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6->-r requirements.txt (line 3)) (1.8.13)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6->-r requirements.txt (line 3)) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6->-r requirements.txt (line 3)) (0.1.7)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6->-r requirements.txt (line 3)) (1.6.0)
# Requirement already satisfied: psutil in ./.venv/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6->-r requirements.txt (line 3)) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in ./.venv/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.6->-r requirements.txt (line 3)) (26.4.0)
# Requirement already satisfied: decorator in ./.venv/lib/python3.11/site-packages (from ipython->jupyterlab==3.6.3->-r requirements.txt (line 2)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in ./.venv/lib/python3.11/site-packages (from ipython->jupyterlab==3.6.3->-r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.11/site-packages (from ipython->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.11/site-packages (from ipython->jupyterlab==3.6.3->-r requirements.txt (line 2)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.11/site-packages (from ipython->jupyterlab==3.6.3->-r requirements.txt (line 2)) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.11/site-packages (from ipython->jupyterlab==3.6.3->-r requirements.txt (line 2)) (2.19.1)
# Requirement already satisfied: stack_data in ./.venv/lib/python3.11/site-packages (from ipython->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in ./.venv/lib/python3.11/site-packages (from ipython->jupyterlab==3.6.3->-r requirements.txt (line 2)) (4.13.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.11/site-packages (from jinja2->altair==5.0.1->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair==5.0.1->-r requirements.txt (line 1)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair==5.0.1->-r requirements.txt (line 1)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair==5.0.1->-r requirements.txt (line 1)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair==5.0.1->-r requirements.txt (line 1)) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.11/site-packages (from jupyter-core->jupyterlab==3.6.3->-r requirements.txt (line 2)) (4.3.7)
# Requirement already satisfied: anyio>=3.1.0 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: jupyter-server-fileid<1,>=0.6.0 in ./.venv/lib/python3.11/site-packages (from jupyter-server-ydoc~=0.8.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.9.3)
# Requirement already satisfied: ypy-websocket<0.9.0,>=0.8.2 in ./.venv/lib/python3.11/site-packages (from jupyter-server-ydoc~=0.8.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.8.4)
# Requirement already satisfied: y-py<0.7.0,>=0.6.0 in ./.venv/lib/python3.11/site-packages (from jupyter-ydoc~=0.2.3->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.6.2)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.11/site-packages (from jupyterlab-server~=2.19->jupyterlab==3.6.3->-r requirements.txt (line 2)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.11/site-packages (from jupyterlab-server~=2.19->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: requests>=2.31 in ./.venv/lib/python3.11/site-packages (from jupyterlab-server~=2.19->jupyterlab==3.6.3->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: ipython-genutils in ./.venv/lib/python3.11/site-packages (from notebook<7->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in ./.venv/lib/python3.11/site-packages (from nbclassic->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.2.4)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib==3.7.1->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in ./.venv/lib/python3.11/site-packages (from dash->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in ./.venv/lib/python3.11/site-packages (from dash->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (3.0.6)
# Requirement already satisfied: plotly>=5.0.0 in ./.venv/lib/python3.11/site-packages (from dash->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (6.0.1)
# Requirement already satisfied: importlib-metadata in ./.venv/lib/python3.11/site-packages (from dash->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (8.6.1)
# Requirement already satisfied: retrying in ./.venv/lib/python3.11/site-packages (from dash->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (1.3.4)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.11/site-packages (from dash->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (65.5.0)
# Requirement already satisfied: aiohttp in ./.venv/lib/python3.11/site-packages (from jupyter-server-proxy->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (3.11.16)
# Requirement already satisfied: simpervisor>=1.0.0 in ./.venv/lib/python3.11/site-packages (from jupyter-server-proxy->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (21.2.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in ./.venv/lib/python3.11/site-packages (from Flask<3.1,>=1.0.4->dash->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in ./.venv/lib/python3.11/site-packages (from Flask<3.1,>=1.0.4->dash->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in ./.venv/lib/python3.11/site-packages (from Flask<3.1,>=1.0.4->dash->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (1.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.11/site-packages (from jedi>=0.16->ipython->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.8.4)
# Requirement already satisfied: entrypoints in ./.venv/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==8.0.6->-r requirements.txt (line 3)) (0.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in ./.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in ./.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (6.2.0)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.venv/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (2.21.1)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.11/site-packages (from pexpect>4.3->ipython->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: narwhals>=1.15.1 in ./.venv/lib/python3.11/site-packages (from plotly>=5.0.0->dash->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (1.33.0)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server~=2.19->jupyterlab==3.6.3->-r requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server~=2.19->jupyterlab==3.6.3->-r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server~=2.19->jupyterlab==3.6.3->-r requirements.txt (line 2)) (2025.1.31)
# Requirement already satisfied: aiofiles<23,>=22.1.0 in ./.venv/lib/python3.11/site-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (22.1.0)
# Requirement already satisfied: aiosqlite<1,>=0.17.0 in ./.venv/lib/python3.11/site-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.21.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./.venv/lib/python3.11/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.11/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.11/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.11/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (6.3.2)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.11/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.11/site-packages (from aiohttp->jupyter-server-proxy->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (1.18.3)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.11/site-packages (from importlib-metadata->dash->jupyterlab-dash==0.1.0a3->-r requirements.txt (line 8)) (3.21.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.11/site-packages (from stack_data->ipython->jupyterlab==3.6.3->-r requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.11/site-packages (from stack_data->ipython->jupyterlab==3.6.3->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.11/site-packages (from stack_data->ipython->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.2.3)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in ./.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in ./.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in ./.venv/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (2.6)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.16.0->jupyterlab==3.6.3->-r requirements.txt (line 2)) (2.9.0.20241206)

# %%
#
# basics
import pandas as pd
import numpy as np

# plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
sns.set_palette('magma')
from sklearn.model_selection import train_test_split
import missingno as msno
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import mean_absolute_error


# warnings
import warnings
warnings.filterwarnings('ignore')

RSEED = 42

# %% [markdown]
# # EDA

# %%
# load training data
df = pd.read_csv('data/Train.csv')

# %%
df_raw = df.copy()

# %%
import matplotlib.pyplot as plt
def plot_nas(df: pd.DataFrame):
    if df.isnull().sum().sum() != 0:
        na_df = (df.isnull().sum() / len(df)) * 100      
        na_df = na_df.drop(na_df[na_df == 0].index).sort_values(ascending=False)
        missing_data = pd.DataFrame({'Missing Ratio %' :na_df})
        missing_data.plot(kind = "barh")
        plt.show()
    else:
        print('No NAs found')
plot_nas(df)
plot_width, plot_height = (15,15)
plt.rcParams['figure.figsize'] = (plot_width,plot_height)
plt.rcParams['ytick.labelsize'] = 9

# %%
# drop columns with more than 50% missing values
check_ch4 = [col for col in df.columns if 'CH4' in col]
df.drop(columns=check_ch4, axis=1, inplace=True)

# Convert to datetime
df["Date"] = pd.to_datetime(df["Date"])

# Create integer column for weekends
df["IsWeek"] = (df["Date"].dt.weekday < 5).astype(int)


df.drop(columns=['Date', 'Place_ID', 'Place_ID X Date', 'target_min', 'target_max', 'target_variance', 'target_count'], axis=1, inplace=True)

df.head(5)
# Out:
#    target  precipitable_water_entire_atmosphere
# 0    38.0                             11.000000  \
# 1    39.0                             14.600000
# 2    24.0                             16.400000
# 3    49.0                              6.911948
# 4    21.0                             13.900001
#
#    relative_humidity_2m_above_ground  specific_humidity_2m_above_ground
# 0                          60.200001                            0.00804  \
# 1                          48.799999                            0.00839
# 2                          33.400002                            0.00750
# 3                          21.300001                            0.00391
# 4                          44.700001                            0.00535
#
#    temperature_2m_above_ground  u_component_of_wind_10m_above_ground
# 0                    18.516840                              1.996377  \
# 1                    22.546533                              3.330430
# 2                    27.031030                              5.065727
# 3                    23.971857                              3.004001
# 4                    16.816309                              2.621787
#
#    v_component_of_wind_10m_above_ground  L3_NO2_NO2_column_number_density
# 0                             -1.227395                          0.000074  \
# 1                             -1.188108                          0.000076
# 2                              3.500559                          0.000067
# 3                              1.099468                          0.000083
# 4                              2.670559                          0.000070
#
#    L3_NO2_NO2_slant_column_number_density  L3_NO2_absorbing_aerosol_index
# 0                                0.000156                       -1.231330  \
# 1                                0.000197                       -1.082553
# 2                                0.000170                       -1.001242
# 3                                0.000175                       -0.777019
# 4                                0.000142                        0.366323
#
#    ...  L3_SO2_SO2_column_number_density
# 0  ...                         -0.000127  \
# 1  ...                          0.000150
# 2  ...                          0.000150
# 3  ...                          0.000227
# 4  ...                          0.000390
#
#    L3_SO2_SO2_column_number_density_amf
# 0                              0.312521  \
# 1                              0.433957
# 2                              0.356925
# 3                              0.584522
# 4                              0.408047
#
#    L3_SO2_SO2_slant_column_number_density  L3_SO2_absorbing_aerosol_index
# 0                               -0.000040                       -1.861476  \
# 1                                0.000050                       -1.452612
# 2                                0.000053                       -1.572950
# 3                                0.000110                       -1.239317
# 4                                0.000159                        0.202489
#
#    L3_SO2_cloud_fraction  L3_SO2_sensor_azimuth_angle
# 0               0.000000                    76.536426  \
# 1               0.059433                   -14.708036
# 2               0.082063                  -105.201338
# 3               0.121261                  -104.334066
# 4               0.037919                    58.850179
#
#    L3_SO2_sensor_zenith_angle  L3_SO2_solar_azimuth_angle
# 0                   38.593017                  -61.752587  \
# 1                   59.624912                  -67.693509
# 2                   49.839714                  -78.342701
# 3                   29.181258                  -73.896588
# 4                    0.797294                  -68.612480
#
#    L3_SO2_solar_zenith_angle  IsWeek
# 0                  22.363665       1
# 1                  28.614804       1
# 2                  34.296977       0
# 3                  30.545446       0
# 4                  26.899694       1
#
# [5 rows x 69 columns]

# %%
msno.matrix(df.query('IsWeek == 1'), fontsize=10,labels=True)
# Out:
# <Axes: >

# %%
msno.matrix(df.query('IsWeek == 0'), fontsize=10,labels=True)
# Out:
# <Axes: >

# %%
#removes 0 as outliers
variables_list_0_as_outlier = [
    "L3_NO2_NO2_column_number_density",
    "L3_NO2_NO2_slant_column_number_density",
    "L3_NO2_sensor_altitude",
    "L3_NO2_tropopause_pressure",
    "L3_NO2_solar_zenith_angle",
    "L3_SO2_SO2_column_number_density",
    "L3_SO2_SO2_column_number_density_amf",
    "L3_SO2_SO2_slant_column_number_density",
    "L3_SO2_solar_zenith_angle",
    "L3_O3_O3_column_number_density",
    "L3_O3_O3_effective_temperature",
    "L3_O3_solar_zenith_angle",
    "L3_CO_CO_column_number_density",
    "L3_CO_sensor_altitude",
    "L3_CO_solar_zenith_angle",
    "L3_HCHO_solar_zenith_angle",
    "L3_HCHO_tropospheric_HCHO_column_number_density_amf"
]

df[variables_list_0_as_outlier].replace(0, np.nan, inplace=True)

# %%
msno.matrix(df, fontsize=10,labels=True)
# Out:
# <Axes: >

# %%
X = df.drop("target", axis=1)
y = df.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RSEED)

# Concatenate X_test and y_test along columns
df_test = pd.concat([X_test, y_test], axis=1)

df_test
# Out:
#        precipitable_water_entire_atmosphere
# 24141                             53.406593  \
# 26865                             19.400000
# 22772                              9.020000
# 25624                              5.600000
# 21690                             21.328571
# ...                                     ...
# 12927                             17.900000
# 22813                             13.360000
# 20033                              5.900000
# 5550                               2.680000
# 27785                             14.700000
#
#        relative_humidity_2m_above_ground  specific_humidity_2m_above_ground
# 24141                          90.000000                           0.016510  \
# 26865                          77.400002                           0.010510
# 22772                          79.900002                           0.004517
# 25624                          23.800001                           0.001301
# 21690                          43.528574                           0.008963
# ...                                  ...                                ...
# 12927                          77.700005                           0.005870
# 22813                          64.780003                           0.004694
# 20033                          93.500000                           0.002955
# 5550                           93.559999                           0.000489
# 27785                          90.599998                           0.004530
#
#        temperature_2m_above_ground  u_component_of_wind_10m_above_ground
# 24141                    23.741449                             -0.583538  \
# 26865                    18.312189                              0.162092
# 22772                     5.800287                             -0.878917
# 25624                     2.700800                              0.576992
# 21690                    21.113977                             -3.136273
# ...                            ...                                   ...
# 12927                     9.581873                              0.357944
# 22813                     9.213770                              3.873460
# 20033                    -3.558630                              1.918855
# 5550                    -22.045697                              1.207083
# 27785                     4.011865                             -1.002056
#
#        v_component_of_wind_10m_above_ground  L3_NO2_NO2_column_number_density
# 24141                             -0.383643                          0.000045  \
# 26865                             -1.166543                          0.000065
# 22772                              4.664847                          0.000082
# 25624                             -1.192380                          0.000178
# 21690                             -2.485902                          0.000000
# ...                                     ...                               ...
# 12927                             -0.636741                          0.000000
# 22813                             -4.871784                          0.000000
# 20033                             -0.320720                          0.000063
# 5550                              -2.105153                          0.000092
# 27785                             -2.586741                          0.000000
#
#        L3_NO2_NO2_slant_column_number_density  L3_NO2_absorbing_aerosol_index
# 24141                                0.000106                       -1.978756  \
# 26865                                0.000180                       -0.776759
# 22772                                0.000156                       -1.286913
# 25624                                0.000307                       -0.999631
# 21690                                0.000000                        0.000000
# ...                                       ...                             ...
# 12927                                0.000000                        0.000000
# 22813                                0.000000                        0.000000
# 20033                                0.000172                       -1.204392
# 5550                                 0.000224                       -0.988050
# 27785                                0.000000                        0.000000
#
#        L3_NO2_cloud_fraction  ...  L3_SO2_SO2_column_number_density_amf
# 24141               0.286723  ...                              0.509832  \
# 26865               0.075896  ...                              0.345039
# 22772               0.131030  ...                              0.147865
# 25624               0.019142  ...                              0.316978
# 21690               0.000000  ...                              0.000000
# ...                      ...  ...                                   ...
# 12927               0.000000  ...                                   NaN
# 22813               0.000000  ...                                   NaN
# 20033               0.382148  ...                              0.731876
# 5550                0.000000  ...                              0.633687
# 27785               0.000000  ...                              0.611604
#
#        L3_SO2_SO2_slant_column_number_density  L3_SO2_absorbing_aerosol_index
# 24141                               -0.000212                       -2.336949  \
# 26865                                0.000146                       -1.066256
# 22772                                0.000029                       -1.899117
# 25624                                0.000251                       -1.767336
# 21690                                0.000000                        0.000000
# ...                                       ...                             ...
# 12927                                     NaN                             NaN
# 22813                                     NaN                             NaN
# 20033                                0.000503                       -2.913432
# 5550                                 0.000092                       -1.664141
# 27785                                0.000079                       -1.941077
#
#        L3_SO2_cloud_fraction  L3_SO2_sensor_azimuth_angle
# 24141               0.431242                    70.300267  \
# 26865               0.236374                   -13.328791
# 22772               0.138355                    22.709713
# 25624               0.004995                    75.817160
# 21690               0.000000                     0.000000
# ...                      ...                          ...
# 12927                    NaN                          NaN
# 22813                    NaN                          NaN
# 20033               0.441868                  -100.336506
# 5550                0.325371                    68.123189
# 27785               0.296686                   -51.227849
#
#        L3_SO2_sensor_zenith_angle  L3_SO2_solar_azimuth_angle
# 24141                   60.601157                 -152.358020  \
# 26865                   65.172025                 -158.038725
# 22772                   51.530494                   91.581413
# 25624                    1.761258                 -166.926480
# 21690                    0.000000                    0.000000
# ...                           ...                         ...
# 12927                         NaN                         NaN
# 22813                         NaN                         NaN
# 20033                   23.080053                 -162.839165
# 5550                    31.399015                 -175.340200
# 27785                   42.096928                  -54.555694
#
#        L3_SO2_solar_zenith_angle  IsWeek  target
# 24141                  16.989528       1    79.0
# 26865                  45.642109       1   129.0
# 22772                  59.373319       1    72.0
# 25624                  61.147652       0    34.0
# 21690                   0.000000       1    61.0
# ...                          ...     ...     ...
# 12927                        NaN       0    75.0
# 22813                        NaN       1    96.0
# 20033                  61.827230       1    95.0
# 5550                   58.047557       1    68.0
# 27785                  45.846615       0   123.0
#
# [6112 rows x 69 columns]

# %% [markdown]
# ## Pipeline

# %%
# Pipeline XGBoost Regression

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import  StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import xgboost as xgb

features = list(X.columns)

num_pipeline = Pipeline([
    ('imputer_num', SimpleImputer(strategy='median')),
    ('std_scaler', StandardScaler())
])

preprocessor = ColumnTransformer([
    ('num', num_pipeline, features),
])

pipe_xgbreg = Pipeline([
    ('preprocessor', preprocessor),
    ('xgbreg', xgb.XGBRegressor(eta = 0.1, n_estimators=50,max_depth=10, colsample_bytree=0.8,gamma=5,reg_alpha=0,reg_lambda=10 )) 
])

pipe_xgbreg
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('std_scaler',
#                                                                    StandardScaler())]),
#                                                   ['precipitable_water_entire_atmosphere',
#                                                    'relative_humidity_2m_above_ground',
#                                                    'specific_humidity_2m_above_ground',
#                                                    'temperature_2m_above_ground',
#                                                    'u_component_of_wind_10m_above_ground'...
#                               eval_metric=None, feature_types=None, gamma=5,
#                               gpu_id=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=10, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, n_estimators=50,
#                               n_jobs=None, num_parallel_tree=None,
#                               predictor=None, ...))])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


pipe_xgbreg.fit(X_train, y_train)

y_pred_test = pipe_xgbreg.predict(X_test)
y_pred_train = pipe_xgbreg.predict(X_train)

mse_test = mean_squared_error(y_test, y_pred_test)
rmse_test = mse_test ** 0.5
mae_test = mean_absolute_error(y_test, y_pred_test)
r2_test = r2_score(y_test, y_pred_test)

mse = mean_squared_error(y_train, y_pred_train)
rmse = mse ** 0.5
mae = mean_absolute_error(y_train, y_pred_train)
r2 = r2_score(y_train, y_pred_train)
              
            
print(f"TEST: RMSE: {rmse_test:.2f}, MAE: {mae_test:.2f}, R²: {r2_test:.3f}")
print(f"train: RMSE: {rmse:.2f}, MAE: {mae:.2f}, R²: {r2:.3f}")
# Out:
# TEST: RMSE: 30.00, MAE: 19.90, R²: 0.591
# train: RMSE: 20.20, MAE: 13.16, R²: 0.814

# %% [markdown]
# ## RandomSearch

# %%
# param_xgbreg = {
#               'xgbreg__n_estimators': [30],
#               'xgbreg__learning_rate': [0.08, 0.1, 0.14], 
#               'xgbreg__max_depth': [ 7, 8,],
#               'xgbreg__colsample_bytree': [0.7, 0.8, 1],
#               'xgbreg__gamma': [0.2, 0.3, 0.5],
#               'xgbreg__reg_alpha': [0],
#               'xgbreg__reg_lambda': [5, 10]
#             }

# random_search_xbreg = RandomizedSearchCV(pipe_xgbreg, param_distributions=param_xgbreg, cv=5, scoring='neg_mean_absolute_error', 
#                            verbose=1, n_jobs=-1, n_iter=50)

# random_search_xbreg.fit(X_train, y_train)
# random_search_xbreg.best_params_, random_search_xbreg.best_score_

# %%
# best_model = random_search_xbreg.best_estimator_
# y_test_predicted = best_model.predict(X_test)
# y_train_predicted = best_model.predict(X_train)

# print("mean_absolute_error: {:.2f}".format(mean_absolute_error(y_test, y_test_predicted)))
# print("mean_absolute_error_train: {:.2f}".format(mean_absolute_error(y_train, y_train_predicted)))

# %% [markdown]
# # GRIDSEARCH Finetuning

# %%
#GRIDSEARCH

param_xgbreg_grid = {
              'xgbreg__n_estimators': [50],
              'xgbreg__learning_rate': [0.1], 
              'xgbreg__max_depth': [10],
              'xgbreg__colsample_bytree': [0.8],
              'xgbreg__gamma': [5],
              'xgbreg__reg_alpha': [0],
              'xgbreg__reg_lambda': [10]
            }

grid_search_xbreg = GridSearchCV(pipe_xgbreg, param_grid=param_xgbreg_grid, cv=5, scoring='neg_mean_absolute_error', 
                           verbose=1, n_jobs=-1)

grid_search_xbreg.fit(X_train, y_train)
grid_search_xbreg.best_params_, grid_search_xbreg.best_score_
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# ({'xgbreg__colsample_bytree': 0.8,
#   'xgbreg__gamma': 5,
#   'xgbreg__learning_rate': 0.1,
#   'xgbreg__max_depth': 10,
#   'xgbreg__n_estimators': 50,
#   'xgbreg__reg_alpha': 0,
#   'xgbreg__reg_lambda': 10},
#  -20.057701191035093)

# %%
best_model = grid_search_xbreg.best_estimator_
# y_test_predicted_grid = best_model.predict(X_test)
# y_train_predicted_grid = best_model.predict(X_train)

# print("mean_absolute_error: {:.2f}".format(mean_absolute_error(y_test, y_test_predicted_grid)))
# print("mean_absolute_error_train: {:.2f}".format(mean_absolute_error(y_train, y_train_predicted_grid)))

# %% [markdown]
# # Error Analyse

# %%
##

residuals = y_train-y_pred_train 

plt.scatter(x=y_pred_train,y=residuals)

plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.title("Residuals vs. Predicted")
# Out:
# Text(0.5, 1.0, 'Residuals vs. Predicted')

# %%
sns.histplot(residuals)

plt.title("Distribution of Residuals")
# Out:
# Text(0.5, 1.0, 'Distribution of Residuals')

# %%
plt.scatter(y_train, y_pred_train, alpha=0.5)
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'b--')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs. Predicted")
# Out:
# Text(0.5, 1.0, 'Actual vs. Predicted')

# %%
reg = best_model.named_steps['xgbreg']
importances = reg.feature_importances_
feature_names = X_train.columns
# Visualize
sns.barplot(x=importances, y=feature_names)
plt.title("Feature Importances")
# Out:
# Text(0.5, 1.0, 'Feature Importances')

# %%
error = np.abs(y_pred_train - y_train)

# %%
df_erroranalyse = X_train.copy()
df_erroranalyse['y_true'] = y_train
df_erroranalyse['y_pred'] = y_pred_train
df_erroranalyse['abs_error'] = error
df_erroranalyse["rel_error"] = error/y_pred_train#df_erroranalyse["y_true"]

# %%
df_erroranalyse.fillna(df.median(),inplace=True)

# %%
top_fehler = df_erroranalyse.sort_values(by='abs_error', ascending=False).head(10)
top_fehler
# Out:
#        precipitable_water_entire_atmosphere
# 4453                               8.471429  \
# 4456                              12.528572
# 4465                               9.671429
# 8173                              28.878614
# 30300                              5.216144
# 25822                             29.200001
# 17607                             11.700000
# 17630                             14.500000
# 25234                             11.800000
# 23123                             12.200000
#
#        relative_humidity_2m_above_ground  specific_humidity_2m_above_ground
# 4453                           23.442857                           0.004474  \
# 4456                           29.471429                           0.006174
# 4465                           15.171429                           0.004068
# 8173                           41.366667                           0.007327
# 30300                          81.120001                           0.002777
# 25822                          68.500000                           0.008554
# 17607                          56.200001                           0.004330
# 17630                          61.900002                           0.005060
# 25234                          98.500000                           0.004610
# 23123                          61.000000                           0.002970
#
#        temperature_2m_above_ground  u_component_of_wind_10m_above_ground
# 4453                     20.786388                              1.051566  \
# 4456                     22.243524                              4.833642
# 4465                     26.412230                             -0.850091
# 8173                     22.028548                             -3.665998
# 30300                    -2.808209                             -0.187060
# 25822                    17.692560                             -1.536594
# 17607                     9.991022                              0.135728
# 17630                    10.800195                             -1.287849
# 25234                    -0.017920                             -0.636357
# 23123                     3.734949                             -2.441509
#
#        v_component_of_wind_10m_above_ground  L3_NO2_NO2_column_number_density
# 4453                               2.760782                          0.000059  \
# 4456                               3.617324                          0.000046
# 4465                              -2.750546                          0.000077
# 8173                               0.369468                          0.000105
# 30300                             -0.479011                          0.000052
# 25822                             -0.055513                          0.000088
# 17607                              0.520559                          0.000144
# 17630                             -0.549910                          0.000073
# 25234                              1.038752                          0.000054
# 23123                             -3.679885                          0.000075
#
#        L3_NO2_NO2_slant_column_number_density  L3_NO2_absorbing_aerosol_index
# 4453                                 0.000121                       -0.659029  \
# 4456                                 0.000119                       -0.814485
# 4465                                 0.000157                       -1.496870
# 8173                                 0.000208                        3.827045
# 30300                                0.000124                       -1.289869
# 25822                                0.000149                        0.038799
# 17607                                0.000187                       -1.272483
# 17630                                0.000149                       -0.769812
# 25234                                0.000138                       -0.734078
# 23123                                0.000150                       -1.168333
#
#        L3_NO2_cloud_fraction  ...  L3_SO2_cloud_fraction
# 4453                0.002930  ...               0.003499  \
# 4456                0.278440  ...               0.359894
# 4465                0.050011  ...               0.080639
# 8173                0.298012  ...               0.349906
# 30300               0.823565  ...               0.190333
# 25822               0.854838  ...               0.190333
# 17607               0.283986  ...               0.294302
# 17630               0.860627  ...               0.190333
# 25234               0.974935  ...               0.190333
# 23123               0.149430  ...               0.190333
#
#        L3_SO2_sensor_azimuth_angle  L3_SO2_sensor_zenith_angle
# 4453                     76.041288                    8.056621  \
# 4456                    -94.545837                   57.442645
# 4465                     70.281991                   46.851716
# 8173                     76.270666                   19.202997
# 30300                   -14.308518                   37.918838
# 25822                   -14.308518                   37.918838
# 17607                    70.431013                   36.955452
# 17630                   -14.308518                   37.918838
# 25234                   -14.308518                   37.918838
# 23123                   -14.308518                   37.918838
#
#        L3_SO2_solar_azimuth_angle  L3_SO2_solar_zenith_angle  IsWeek  y_true
# 4453                  -157.709027                  39.146939       0   815.0  \
# 4456                  -142.722236                  43.375964       1   815.0
# 4465                  -165.142246                  33.428196       1   815.0
# 8173                   -66.029434                  24.776411       0   689.0
# 30300                 -156.637162                  47.445010       0   465.0
# 25822                 -156.637162                  47.445010       1   343.0
# 17607                 -168.578931                  55.190426       0   400.0
# 17630                 -156.637162                  47.445010       1   278.0
# 25234                 -156.637162                  47.445010       1   287.0
# 23123                 -156.637162                  47.445010       1   303.0
#
#            y_pred   abs_error  rel_error
# 4453   286.225555  528.774445   1.847405
# 4456   290.955170  524.044830   1.801119
# 4465   293.251678  521.748322   1.779183
# 8173   272.722626  416.277374   1.526376
# 30300  129.924088  335.075912   2.579013
# 25822  119.982224  223.017776   1.858757
# 17607  205.882294  194.117706   0.942858
# 17630   86.415627  191.584373   2.217011
# 25234  108.124092  178.875908   1.654358
# 23123  128.768906  174.231094   1.353053
#
# [10 rows x 72 columns]

# %%
top_fehler.columns
# Out:
# Index(['precipitable_water_entire_atmosphere',
#        'relative_humidity_2m_above_ground',
#        'specific_humidity_2m_above_ground', 'temperature_2m_above_ground',
#        'u_component_of_wind_10m_above_ground',
#        'v_component_of_wind_10m_above_ground',
#        'L3_NO2_NO2_column_number_density',
#        'L3_NO2_NO2_slant_column_number_density',
#        'L3_NO2_absorbing_aerosol_index', 'L3_NO2_cloud_fraction',
#        'L3_NO2_sensor_altitude', 'L3_NO2_sensor_azimuth_angle',
#        'L3_NO2_sensor_zenith_angle', 'L3_NO2_solar_azimuth_angle',
#        'L3_NO2_solar_zenith_angle',
#        'L3_NO2_stratospheric_NO2_column_number_density',
#        'L3_NO2_tropopause_pressure',
#        'L3_NO2_tropospheric_NO2_column_number_density',
#        'L3_O3_O3_column_number_density', 'L3_O3_O3_effective_temperature',
#        'L3_O3_cloud_fraction', 'L3_O3_sensor_azimuth_angle',
#        'L3_O3_sensor_zenith_angle', 'L3_O3_solar_azimuth_angle',
#        'L3_O3_solar_zenith_angle', 'L3_CO_CO_column_number_density',
#        'L3_CO_H2O_column_number_density', 'L3_CO_cloud_height',
#        'L3_CO_sensor_altitude', 'L3_CO_sensor_azimuth_angle',
#        'L3_CO_sensor_zenith_angle', 'L3_CO_solar_azimuth_angle',
#        'L3_CO_solar_zenith_angle', 'L3_HCHO_HCHO_slant_column_number_density',
#        'L3_HCHO_cloud_fraction', 'L3_HCHO_sensor_azimuth_angle',
#        'L3_HCHO_sensor_zenith_angle', 'L3_HCHO_solar_azimuth_angle',
#        'L3_HCHO_solar_zenith_angle',
#        'L3_HCHO_tropospheric_HCHO_column_number_density',
#        'L3_HCHO_tropospheric_HCHO_column_number_density_amf',
#        'L3_CLOUD_cloud_base_height', 'L3_CLOUD_cloud_base_pressure',
#        'L3_CLOUD_cloud_fraction', 'L3_CLOUD_cloud_optical_depth',
#        'L3_CLOUD_cloud_top_height', 'L3_CLOUD_cloud_top_pressure',
#        'L3_CLOUD_sensor_azimuth_angle', 'L3_CLOUD_sensor_zenith_angle',
#        'L3_CLOUD_solar_azimuth_angle', 'L3_CLOUD_solar_zenith_angle',
#        'L3_CLOUD_surface_albedo', 'L3_AER_AI_absorbing_aerosol_index',
#        'L3_AER_AI_sensor_altitude', 'L3_AER_AI_sensor_azimuth_angle',
#        'L3_AER_AI_sensor_zenith_angle', 'L3_AER_AI_solar_azimuth_angle',
#        'L3_AER_AI_solar_zenith_angle', 'L3_SO2_SO2_column_number_density',
#        'L3_SO2_SO2_column_number_density_amf',
#        'L3_SO2_SO2_slant_column_number_density',
#        'L3_SO2_absorbing_aerosol_index', 'L3_SO2_cloud_fraction',
#        'L3_SO2_sensor_azimuth_angle', 'L3_SO2_sensor_zenith_angle',
#        'L3_SO2_solar_azimuth_angle', 'L3_SO2_solar_zenith_angle', 'IsWeek',
#        'y_true', 'y_pred', 'abs_error', 'rel_error'],
#       dtype='object')

# %%
sns.scatterplot(data=df_erroranalyse, x="y_true", y="rel_error")
# Out:
# <Axes: xlabel='y_true', ylabel='rel_error'>

# %%
best_feature=list(feature_names[importances>0.04])
lst=['y_true','y_pred','abs_error','rel_error']
best_feature.extend(lst)

# best_feature

sns.pairplot(data=df_erroranalyse[best_feature])

# %%
df_raw.columns
# Out:
# Index(['Place_ID X Date', 'Date', 'Place_ID', 'target', 'target_min',
#        'target_max', 'target_variance', 'target_count',
#        'precipitable_water_entire_atmosphere',
#        'relative_humidity_2m_above_ground',
#        'specific_humidity_2m_above_ground', 'temperature_2m_above_ground',
#        'u_component_of_wind_10m_above_ground',
#        'v_component_of_wind_10m_above_ground',
#        'L3_NO2_NO2_column_number_density',
#        'L3_NO2_NO2_slant_column_number_density',
#        'L3_NO2_absorbing_aerosol_index', 'L3_NO2_cloud_fraction',
#        'L3_NO2_sensor_altitude', 'L3_NO2_sensor_azimuth_angle',
#        'L3_NO2_sensor_zenith_angle', 'L3_NO2_solar_azimuth_angle',
#        'L3_NO2_solar_zenith_angle',
#        'L3_NO2_stratospheric_NO2_column_number_density',
#        'L3_NO2_tropopause_pressure',
#        'L3_NO2_tropospheric_NO2_column_number_density',
#        'L3_O3_O3_column_number_density', 'L3_O3_O3_effective_temperature',
#        'L3_O3_cloud_fraction', 'L3_O3_sensor_azimuth_angle',
#        'L3_O3_sensor_zenith_angle', 'L3_O3_solar_azimuth_angle',
#        'L3_O3_solar_zenith_angle', 'L3_CO_CO_column_number_density',
#        'L3_CO_H2O_column_number_density', 'L3_CO_cloud_height',
#        'L3_CO_sensor_altitude', 'L3_CO_sensor_azimuth_angle',
#        'L3_CO_sensor_zenith_angle', 'L3_CO_solar_azimuth_angle',
#        'L3_CO_solar_zenith_angle', 'L3_HCHO_HCHO_slant_column_number_density',
#        'L3_HCHO_cloud_fraction', 'L3_HCHO_sensor_azimuth_angle',
#        'L3_HCHO_sensor_zenith_angle', 'L3_HCHO_solar_azimuth_angle',
#        'L3_HCHO_solar_zenith_angle',
#        'L3_HCHO_tropospheric_HCHO_column_number_density',
#        'L3_HCHO_tropospheric_HCHO_column_number_density_amf',
#        'L3_CLOUD_cloud_base_height', 'L3_CLOUD_cloud_base_pressure',
#        'L3_CLOUD_cloud_fraction', 'L3_CLOUD_cloud_optical_depth',
#        'L3_CLOUD_cloud_top_height', 'L3_CLOUD_cloud_top_pressure',
#        'L3_CLOUD_sensor_azimuth_angle', 'L3_CLOUD_sensor_zenith_angle',
#        'L3_CLOUD_solar_azimuth_angle', 'L3_CLOUD_solar_zenith_angle',
#        'L3_CLOUD_surface_albedo', 'L3_AER_AI_absorbing_aerosol_index',
#        'L3_AER_AI_sensor_altitude', 'L3_AER_AI_sensor_azimuth_angle',
#        'L3_AER_AI_sensor_zenith_angle', 'L3_AER_AI_solar_azimuth_angle',
#        'L3_AER_AI_solar_zenith_angle', 'L3_SO2_SO2_column_number_density',
#        'L3_SO2_SO2_column_number_density_amf',
#        'L3_SO2_SO2_slant_column_number_density',
#        'L3_SO2_absorbing_aerosol_index', 'L3_SO2_cloud_fraction',
#        'L3_SO2_sensor_azimuth_angle', 'L3_SO2_sensor_zenith_angle',
#        'L3_SO2_solar_azimuth_angle', 'L3_SO2_solar_zenith_angle',
#        'L3_CH4_CH4_column_volume_mixing_ratio_dry_air',
#        'L3_CH4_aerosol_height', 'L3_CH4_aerosol_optical_depth',
#        'L3_CH4_sensor_azimuth_angle', 'L3_CH4_sensor_zenith_angle',
#        'L3_CH4_solar_azimuth_angle', 'L3_CH4_solar_zenith_angle'],
#       dtype='object')

# %%
import plotly.express as px
# Create the plot
fig = px.line(df_raw, x="Date", y="target")
# Customize the x-axis
fig.update_xaxes(ticks= "outside",
                 dtick= "M1",
                 ticklabelmode= "period",
                 tickcolor= "black",
                 ticklen=10,
                 minor=dict(
                     ticklen=4,
                     dtick=7*24*60*60*1000,
                     tick0="2016-07-03",
                     griddash='dot',
                     gridcolor='white',
                     tickcolor="lightgrey")
                )
fig.update_layout({"title": 'Daily PM2.5 concentration for 340 cities across the globe',
                   "xaxis": {"title":"Months"},
                   "yaxis": {"title":"Daily PM2.5 concentration"},
                   "showlegend": False})
# Show the plot
fig.show()

# %%
import pandas as pd
import plotly.express as px

# Group the data to get the mean target per day
df_grouped = df_raw.groupby("Date", as_index=False)["target"].mean()

# Create the plot with the grouped data
fig = px.line(df_grouped, x="Date", y="target")

# Customize the x-axis
fig.update_xaxes(
    ticks="outside",
    dtick="M1",
    ticklabelmode="period",
    tickcolor="black",
    ticklen=10,
    minor=dict(
        ticklen=4,
        dtick=7*24*60*60*1000,  # 7 days in milliseconds
        tick0="2016-07-03",
        griddash='dot',
        gridcolor='white',
        tickcolor="lightgrey"
    )
)

# Update layout
fig.update_layout({
    "title": 'Daily Average PM2.5 Concentration for 340 Cities Across the Globe',
    "xaxis": {"title": "Months"},
    "yaxis": {"title": "Daily Average PM2.5 Concentration"},
    "showlegend": False
})

# Show the plot
fig.show()

# %%
y_pred_test
# Out:
# array([ 59.78723, 109.03346,  48.05819, ...,  68.55142, 128.72705,
#         69.10888], dtype=float32)

# %%
df2 = pd.read_csv('data/train.csv')
X_2 = df2.drop("target", axis=1)
y_2 = df2.target

# Convert to datetime
df2["Date"] = pd.to_datetime(df2["Date"])

X_2train, X_2test, y_2train, y_2test = train_test_split(X_2, y_2, test_size=0.2, random_state=RSEED)

# Concatenate X_test and y_test along columns
df2_test = pd.concat([X_2test, y_2test], axis=1)
df2_test['y_pred'] = y_pred_test

# %%
df2_test.columns
# Out:
# Index(['Place_ID X Date', 'Date', 'Place_ID', 'target_min', 'target_max',
#        'target_variance', 'target_count',
#        'precipitable_water_entire_atmosphere',
#        'relative_humidity_2m_above_ground',
#        'specific_humidity_2m_above_ground', 'temperature_2m_above_ground',
#        'u_component_of_wind_10m_above_ground',
#        'v_component_of_wind_10m_above_ground',
#        'L3_NO2_NO2_column_number_density',
#        'L3_NO2_NO2_slant_column_number_density',
#        'L3_NO2_absorbing_aerosol_index', 'L3_NO2_cloud_fraction',
#        'L3_NO2_sensor_altitude', 'L3_NO2_sensor_azimuth_angle',
#        'L3_NO2_sensor_zenith_angle', 'L3_NO2_solar_azimuth_angle',
#        'L3_NO2_solar_zenith_angle',
#        'L3_NO2_stratospheric_NO2_column_number_density',
#        'L3_NO2_tropopause_pressure',
#        'L3_NO2_tropospheric_NO2_column_number_density',
#        'L3_O3_O3_column_number_density', 'L3_O3_O3_effective_temperature',
#        'L3_O3_cloud_fraction', 'L3_O3_sensor_azimuth_angle',
#        'L3_O3_sensor_zenith_angle', 'L3_O3_solar_azimuth_angle',
#        'L3_O3_solar_zenith_angle', 'L3_CO_CO_column_number_density',
#        'L3_CO_H2O_column_number_density', 'L3_CO_cloud_height',
#        'L3_CO_sensor_altitude', 'L3_CO_sensor_azimuth_angle',
#        'L3_CO_sensor_zenith_angle', 'L3_CO_solar_azimuth_angle',
#        'L3_CO_solar_zenith_angle', 'L3_HCHO_HCHO_slant_column_number_density',
#        'L3_HCHO_cloud_fraction', 'L3_HCHO_sensor_azimuth_angle',
#        'L3_HCHO_sensor_zenith_angle', 'L3_HCHO_solar_azimuth_angle',
#        'L3_HCHO_solar_zenith_angle',
#        'L3_HCHO_tropospheric_HCHO_column_number_density',
#        'L3_HCHO_tropospheric_HCHO_column_number_density_amf',
#        'L3_CLOUD_cloud_base_height', 'L3_CLOUD_cloud_base_pressure',
#        'L3_CLOUD_cloud_fraction', 'L3_CLOUD_cloud_optical_depth',
#        'L3_CLOUD_cloud_top_height', 'L3_CLOUD_cloud_top_pressure',
#        'L3_CLOUD_sensor_azimuth_angle', 'L3_CLOUD_sensor_zenith_angle',
#        'L3_CLOUD_solar_azimuth_angle', 'L3_CLOUD_solar_zenith_angle',
#        'L3_CLOUD_surface_albedo', 'L3_AER_AI_absorbing_aerosol_index',
#        'L3_AER_AI_sensor_altitude', 'L3_AER_AI_sensor_azimuth_angle',
#        'L3_AER_AI_sensor_zenith_angle', 'L3_AER_AI_solar_azimuth_angle',
#        'L3_AER_AI_solar_zenith_angle', 'L3_SO2_SO2_column_number_density',
#        'L3_SO2_SO2_column_number_density_amf',
#        'L3_SO2_SO2_slant_column_number_density',
#        'L3_SO2_absorbing_aerosol_index', 'L3_SO2_cloud_fraction',
#        'L3_SO2_sensor_azimuth_angle', 'L3_SO2_sensor_zenith_angle',
#        'L3_SO2_solar_azimuth_angle', 'L3_SO2_solar_zenith_angle',
#        'L3_CH4_CH4_column_volume_mixing_ratio_dry_air',
#        'L3_CH4_aerosol_height', 'L3_CH4_aerosol_optical_depth',
#        'L3_CH4_sensor_azimuth_angle', 'L3_CH4_sensor_zenith_angle',
#        'L3_CH4_solar_azimuth_angle', 'L3_CH4_solar_zenith_angle', 'target',
#        'y_pred'],
#       dtype='object')

# %%
# Group the data to get the mean target per day
df2_grouped = df2_test.groupby('Date', as_index=False)['y_pred'].mean()

# Create the plot with the grouped data
fig = px.line(df2_grouped, x="Date", y="y_pred")

# Customize the x-axis
fig.update_xaxes(
    ticks="outside",
    dtick="M1",
    ticklabelmode="period",
    tickcolor="black",
    ticklen=10,
    minor=dict(
        ticklen=4,
        dtick=7*24*60*60*1000,  # 7 days in milliseconds
        tick0="2016-07-03",
        griddash='dot',
        gridcolor='white',
        tickcolor="lightgrey"
    )
)

# Update layout
fig.update_layout({
    "title": 'Daily Average PM2.5 Concentration for 340 Cities Across the Globe',
    "xaxis": {"title": "Months"},
    "yaxis": {"title": "Daily Average PM2.5 Concentration"},
    "showlegend": False
})

# Show the plot
fig.show()

# %%
import pandas as pd

# Melt the DataFrame to have 'y_pred' and 'target' as separate series
df_long = pd.melt(df2_test, id_vars=['Date'], value_vars=['y_pred', 'target'],
                  var_name='Series', value_name='Value')

# %%
import pandas as pd
import plotly.express as px
from sklearn.model_selection import train_test_split

df2 = pd.read_csv('data/train.csv')
X_2 = df2.drop("target", axis=1)
y_2 = df2.target

# Convert to datetime
df2["Date"] = pd.to_datetime(df2["Date"])

X_2train, X_2test, y_2train, y_2test = train_test_split(X_2, y_2, test_size=0.2, random_state=RSEED)

# Concatenate X_test and y_test along columns
df2_test = pd.concat([X_2test, y_2test], axis=1)
df2_test['y_pred'] = y_pred_test
# Assuming df2_test is your DataFrame containing 'Date', 'y_pred', and 'target' columns

# Group the data to get the mean of 'y_pred' and 'target' per day
df2_grouped = df2_test.groupby('Date')[['y_pred', 'target']].mean().reset_index()

# Create the plot with the grouped data
fig = px.line(df2_grouped, x='Date', y=['y_pred', 'target'],
              labels={'Date': 'Date', 'value': 'Concentration'},
              title='Daily Average PM2.5 Concentration: Actual vs Predicted')

# Update the legend labels
fig.for_each_trace(lambda t: t.update(name='PM2.5 predicted' if t.name == 'y_pred' else 'PM2.5 actual'))

# Customize the x-axis
fig.update_xaxes(
    ticks="outside",
    dtick="M1",
    ticklabelmode="period",
    tickcolor="black",
    ticklen=10,
    minor=dict(
        ticklen=4,
        dtick=7*24*60*60*1000,  # 7 days in milliseconds
        tick0="2016-07-03",
        griddash='dot',
        gridcolor='white',
        tickcolor="lightgrey"
    )
)

# Update layout
fig.update_layout(
    yaxis_title="Daily Average PM2.5 Concentration",
    showlegend=True
)

# Show the plot
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 16
#      14 # Concatenate X_test and y_test along columns
#      15 df2_test = pd.concat([X_2test, y_2test], axis=1)
# ---> 16 df2_test['y_pred'] = y_pred_test
#      17 # Assuming df2_test is your DataFrame containing 'Date', 'y_pred', and 'target' columns
#      18
#      19 # Group the data to get the mean of 'y_pred' and 'target' per day
#      20 df2_grouped = df2_test.groupby('Date')[['y_pred', 'target']].mean().reset_index()
#
# NameError: name 'y_pred_test' is not defined
